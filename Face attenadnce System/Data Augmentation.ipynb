# %%
import tensorflow as tf
# from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing import image
from tensorflow.keras.preprocessing.image import load_img,img_to_array
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 3
#       1 import tensorflow as tf
#       2 # from tensorflow import keras
# ----> 3 from keras.preprocessing.image import ImageDataGenerator
#       4 from keras.preprocessing import image
#       5 from tensorflow.keras.preprocessing.image import load_img,img_to_array
#
# File ~\anaconda3\envs\tensorflow\lib\site-packages\keras\__init__.py:3
#       1 """AUTOGENERATED. DO NOT EDIT."""
# ----> 3 from keras import __internal__
#       4 from keras import activations
#       5 from keras import applications
#
# File ~\anaconda3\envs\tensorflow\lib\site-packages\keras\__internal__\__init__.py:3
#       1 """AUTOGENERATED. DO NOT EDIT."""
# ----> 3 from keras.__internal__ import backend
#       4 from keras.__internal__ import layers
#       5 from keras.__internal__ import losses
#
# ...

# %%
datagen=ImageDataGenerator(
    rescale=1./255.,
    rotation_range=30,
    width_shift_range=0.20,
    height_shift_range=0.20,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode="nearest"
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 datagen=ImageDataGenerator(
#       2     rescale=1./255.,
#       3     rotation_range=30,
#       4     width_shift_range=0.20,
#       5     height_shift_range=0.20,
#       6     shear_range=0.2,
#       7     zoom_range=0.2,
#       8     horizontal_flip=True,
#       9     fill_mode="nearest"
#      10 )
#
# NameError: name 'ImageDataGenerator' is not defined

# %%
img=load_img("C:\\Users\\rajen\\OneDrive\\Desktop\\Open cv projects\\Train\\Rajendra\\raj5.jpg")
x=img_to_array(img)
x=x.reshape((1,)+x.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 img=load_img("C:\\Users\\rajen\\OneDrive\\Desktop\\Open cv projects\\Train\\Rajendra\\raj5.jpg")
#       2 x=img_to_array(img)
#       3 x=x.reshape((1,)+x.shape)
#
# NameError: name 'load_img' is not defined

# %%
i=0
for batch in datagen.flow(x,batch_size=1,save_to_dir="C:\\Users\\rajen\\OneDrive\\Desktop\\Open cv projects\\Train\\Rajendra",
                          save_prefix="raj"+str(i),
                         save_format="jpg"):
    i=i+1
    if i>10:
        break
