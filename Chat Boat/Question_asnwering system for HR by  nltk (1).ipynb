# %%
from nltk.chat.util import Chat,reflections
import speech_recognition as sr
from gtts import gTTS
import IPython.display as ipd
import os

# %%
pairs=[
    [
        r"(.*)name(.*)",
        ["hello my name is Sweety and i am new Artifical HR in regex Softwere witch is developed by rajendra kumar",]
    ],
    [
        r"(.*)(hii|hi|hello)(.*)",
        ["witch cource your find here"]
    ],
    [
        #Machine learning 
        r"((.*)timing(.*)(machine learning|ml) batch a(.*)|(.*)(machine learning|ml) batch a(.*)timing(.*)|(.*)time(.*)(machine learning|ml) batch a(.*)|(.*)(machine learning|ml) batch a(.*)time(.*)|(.*)batch a (machine learning|ml)(.*)time(.*)|(.*)batch a (machine learning|ml)(.*)timing(.*)|(.*)timing(.*)batch a (machine learning|ml)(.*)|(.*)time(.*)batch a (machine learning|ml)(.*)|(.*)timing(.*)(machine learning|ml) a batch(.*)|(.*)(machine learning|ml) a batch(.*)timing(.*)|(.*)time(.*)(machine learning|ml) a batch(.*)|(.*)(machine learning|ml) a batch(.*)time(.*)|(.*)(ml|machine learning) batch a(.*)|(.*)batch a (ml|machine learning)(.*))",
        ["your batch timing is '12.00 pm to 03.00 pm'"]
    ],
    [
        r"((.*)timing(.*)(machine learning|ml) batch b(.*)|(.*)(machine learning|ml) batch b(.*)timing(.*)|(.*)time(.*)(machine learning|ml) batch b(.*)|(.*)(machine learning|ml) batch b(.*)time(.*)|(.*)batch b (machine learning|ml)(.*)time(.*)|(.*)batch b (machine learning|ml)(.*)timing(.*)|(.*)timing(.*)batch b (machine learning|ml)(.*)|(.*)time(.*)batch b (machine learning|ml)(.*)|(.*)timing(.*)(machine learning|ml) b batch(.*)|(.*)(machine learning|ml) b batch(.*)timing(.*)|(.*)time(.*)(machine learning|ml) b batch(.*)|(.*)(machine learning|ml) b batch(.*)time(.*)|(.*)(ml|machine learning) batch b(.*)|(.*)batch b (ml|machine learning)(.*))",
        ["your batch timing is '05.15 pm to 07.00 pm'"]
    ],
    [
        r"((.*)timing(.*)(machine learning|ml) batch c(.*)|(.*)(machine learning|ml) batch c(.*)timing(.*)|(.*)time(.*)(machine learning|ml) batch c(.*)|(.*)(machine learning|ml) batch c(.*)time(.*)|(.*)batch c (machine learning|ml)(.*)time(.*)|(.*)batch c (machine learning|ml)(.*)timing(.*)|(.*)timing(.*)batch c (machine learning|ml)(.*)|(.*)time(.*)batch c (machine learning|ml)(.*)|(.*)timing(.*)(machine learning|ml) c batch(.*)|(.*)(machine learning|ml) c batch(.*)timing(.*)|(.*)time(.*)(machine learning|ml) c batch(.*)|(.*)(machine learning|ml) c batch(.*)time(.*)|(.*)(ml|machine learning) batch c(.*)|(.*)batch c (ml|machine learning)(.*))",
        ["we Dont have any planing for Machine larning batch c"]
    ],
    [
        r"((.*)timing(.*)(machine learning|ml) batch d(.*)|(.*)(machine learning|ml) batch d(.*)timing(.*)|(.*)time(.*)(machine learning|ml) batch d(.*)|(.*)(machine learning|ml) batch d(.*)time(.*)|(.*)batch d (machine learning|ml)(.*)time(.*)|(.*)batch d (machine learning|ml)(.*)timing(.*)|(.*)timing(.*)batch d (machine learning|ml)(.*)|(.*)time(.*)batch d (machine learning|ml)(.*)|(.*)timing(.*)(machine learning|ml) d batch(.*)|(.*)(machine learning|ml) d batch(.*)timing(.*)|(.*)time(.*)(machine learning|ml) d batch(.*)|(.*)(machine learning|ml) d batch(.*)time(.*)|(.*)(ml|machine learning) batch d(.*)|(.*)batch d (ml|machine learning)(.*))",
        ["your batch timing is '03.15 pm to 05.00 pm'"]
    ],
    [
        r"(.*)(holiday|live|chutti)(.*)",
        ["No your session is very important we will never give you holiday "]
    ],
    [
        r"(.*)(message|information|update)(.*)",
        ["Important message for all : It is mandatory for each and every student to attend their classes tomorrow, as we have an Office Meet tomorrow. If you are unable to attend tomorrow's classes, we kindly request you to send an email to nidhi.sharma@regexsoftware.com, specifying the reason for your absence. Regards Team REGEX"]
    ],
    [
        #java
        r"((.*)timing(.*)java(.*)batch d(.*)|(.*)java(.*)batch d(.*)timing(.*)|(.*)time(.*)java(.*)batch d(.*)|(.*)java(.*)batch d(.*)time(.*)|(.*)batch d java(.*)time(.*)|(.*)batch d java(.*)timing(.*)|(.*)timing(.*)batch d java(.*)|(.*)time(.*)batch d java(.*)|(.*)timing(.*)java(.*)d batch(.*)|(.*)java(.*)d batch(.*)timing(.*)|(.*)time(.*)java(.*)d batch(.*)|(.*)java(.*)d batch(.*)time(.*)|(.*)java batch d(.*)|(.*)batch d java(.*))",
        ["your batch timing is '09.00 am to 10.30 am'"]
    ],
    [
        r"((.*)timing(.*)java(.*)batch b(.*)|(.*)java(.*)batch b(.*)timing(.*)|(.*)time(.*)java(.*)batch b(.*)|(.*)java(.*)batch b(.*)time(.*)|(.*)batch b java(.*)time(.*)|(.*)batch b java(.*)timing(.*)|(.*)timing(.*)batch b java(.*)|(.*)time(.*)batch b java(.*)|(.*)timing(.*)java(.*)b batch(.*)|(.*)java(.*)b batch(.*)timing(.*)|(.*)time(.*)java(.*)b batch(.*)|(.*)java(.*)b batch(.*)time(.*)|(.*)java batch b(.*)|(.*)batch b java(.*))",
        ["your batch timing is '10.30 am to 12.00 pm'"]
    ],
    [
        r"((.*)timing(.*)java(.*)batch a(.*)|(.*)java(.*)batch a(.*)timing(.*)|(.*)time(.*)java(.*)batch a(.*)|(.*)java(.*)batch a(.*)time(.*)|(.*)batch a java(.*)time(.*)|(.*)batch a java(.*)timing(.*)|(.*)timing(.*)batch a java(.*)|(.*)time(.*)batch a java(.*)|(.*)timing(.*)java(.*)a batch(.*)|(.*)java(.*)a batch(.*)timing(.*)|(.*)time(.*)java(.*)a batch(.*)|(.*)java(.*)a batch(.*)time(.*)|(.*)java batch a(.*)|(.*)batch a java(.*))",
        ["your batch timing is '12.15 pm to 01.15 pm'"]
    ],
    [
        r"((.*)timing(.*)java(.*)batch c(.*)|(.*)java(.*)batch c(.*)timing(.*)|(.*)time(.*)java(.*)batch c(.*)|(.*)java(.*)batch c(.*)time(.*)|(.*)batch c java(.*)time(.*)|(.*)batch c java(.*)timing(.*)|(.*)timing(.*)batch c java(.*)|(.*)time(.*)batch c java(.*)|(.*)timing(.*)java(.*)c batch(.*)|(.*)java(.*)c batch(.*)timing(.*)|(.*)time(.*)java(.*)c batch(.*)|(.*)java(.*)c batch(.*)time(.*)|(.*)java batch c(.*)|(.*)batch c java(.*))",
        ["your batch timing is '04.00 pm to 06.00 pm'"]
    ],
    [
        r"((.*)timing(.*)frontend(.*)batch d(.*)|(.*)frontend(.*)batch d(.*)timing(.*)|(.*)time(.*)frontend(.*)batch d(.*)|(.*)frontend(.*)batch d(.*)time(.*)|(.*)batch d frontend(.*)time(.*)|(.*)batch d frontend(.*)timing(.*)|(.*)timing(.*)batch d frontend(.*)|(.*)time(.*)batch d frontend(.*)|(.*)timing(.*)frontend(.*)d batch(.*)|(.*)frontend(.*)d batch(.*)timing(.*)|(.*)time(.*)frontend(.*)d batch(.*)|(.*)frontend(.*)d batch(.*)time(.*)|(.*)frontend batch d(.*)|(.*)batch d frontend(.*))",
        ["your batch timing is '09.00 am to 12.00 pm'"]
    ],
    [
        r"((.*)timing(.*)frontend(.*)batch e(.*)|(.*)frontend(.*)batch e(.*)timing(.*)|(.*)time(.*)frontend(.*)batch e(.*)|(.*)frontend(.*)batch e(.*)time(.*)|(.*)batch e frontend(.*)time(.*)|(.*)batch e frontend(.*)timing(.*)|(.*)timing(.*)batch e frontend(.*)|(.*)time(.*)batch e frontend(.*)|(.*)timing(.*)frontend(.*)e batch(.*)|(.*)frontend(.*)e batch(.*)timing(.*)|(.*)time(.*)frontend(.*)e batch(.*)|(.*)frontend(.*)e batch(.*)time(.*)|(.*)frontend batch e(.*)|(.*)batch e frontend(.*))",
        ["your batch timing is '03.00 pm to 06.00 pm'"]
    ],
    [
        r"((.*)timing(.*)python(.*)batch a(.*)|(.*)python(.*)batch a(.*)timing(.*)|(.*)time(.*)python(.*)batch a(.*)|(.*)python(.*)batch a(.*)time(.*)|(.*)batch a python(.*)time(.*)|(.*)batch a python(.*)timing(.*)|(.*)timing(.*)batch a python(.*)|(.*)time(.*)batch a python(.*)|(.*)timing(.*)python(.*)a batch(.*)|(.*)python(.*)a batch(.*)timing(.*)|(.*)time(.*)python(.*)a batch(.*)|(.*)python(.*)a batch(.*)time(.*)|(.*)python batch a(.*)|(.*)batch a python(.*))",
        ["your batch timing is '12.15 pm to 02.00 pm'"]
    ],
    [
        r"((.*)timing(.*)python(.*)batch b(.*)|(.*)python(.*)batch b(.*)timing(.*)|(.*)time(.*)python(.*)batch b(.*)|(.*)python(.*)batch b(.*)time(.*)|(.*)batch b python(.*)time(.*)|(.*)batch b python(.*)timing(.*)|(.*)timing(.*)batch b python(.*)|(.*)time(.*)batch b python(.*)|(.*)timing(.*)python(.*)b batch(.*)|(.*)python(.*)b batch(.*)timing(.*)|(.*)time(.*)python(.*)b batch(.*)|(.*)python(.*)b batch(.*)time(.*)|(.*)python batch b(.*)|(.*)batch a python(.*))",
        ["your batch timing is '02.15 pm to 04.00 pm'"]
    ],
    [
        r"((.*)timing(.*)(big data|bigdata)(.*)batch a(.*)|(.*)(big data|bigdata)(.*)batch a(.*)timing(.*)|(.*)time(.*)(big data|bigdata)(.*)batch a(.*)|(.*)(big data|bigdata)(.*)batch a(.*)time(.*)|(.*)batch a (big data|bigdata)(.*)time(.*)|(.*)batch a (big data|bigdata)(.*)timing(.*)|(.*)timing(.*)batch a (big data|bigdata)(.*)|(.*)time(.*)batch a (big data|bigdata)(.*)|(.*)timing(.*)(big data|bigdata)(.*)a batch(.*)|(.*)(big data|bigdata)(.*)a batch(.*)timing(.*)|(.*)time(.*)(big data|bigdata)(.*)a batch(.*)|(.*)(big data|bigdata)(.*)a batch(.*)time(.*)|(.*)(big data|bigdata) batch a(.*)|(.*)batch a (big data|bigdata)(.*))",
        ["your batch timing is '04.15 pm to 06.00 pm'"]
    ],
    [
        r"((.*)timing(.*)cpp(.*)batch c(.*)|(.*)cpp(.*)batch c(.*)timing(.*)|(.*)time(.*)cpp(.*)batch c(.*)|(.*)cpp(.*)batch c(.*)time(.*)|(.*)batch c cpp(.*)time(.*)|(.*)batch c cpp(.*)timing(.*)|(.*)timing(.*)batch c cpp(.*)|(.*)time(.*)batch c cpp(.*)|(.*)timing(.*)cpp(.*)c batch(.*)|(.*)cpp(.*)c batch(.*)timing(.*)|(.*)time(.*)cpp(.*)c batch(.*)|(.*)cpp(.*)c batch(.*)time(.*)|(.*)cpp batch c(.*)|(.*)batch c cpp(.*))",
        ["your batch timing is '03.00 pm to 05.00 pm'"]
    ],
    [
        r"((.*)timing(.*)cpp(.*)batch d(.*)|(.*)cpp(.*)batch d(.*)timing(.*)|(.*)time(.*)cpp(.*)batch d(.*)|(.*)cpp(.*)batch d(.*)time(.*)|(.*)batch d cpp(.*)time(.*)|(.*)batch d cpp(.*)timing(.*)|(.*)timing(.*)batch d cpp(.*)|(.*)time(.*)batch d cpp(.*)|(.*)timing(.*)cpp(.*)d batch(.*)|(.*)cpp(.*)d batch(.*)timing(.*)|(.*)time(.*)cpp(.*)d batch(.*)|(.*)cpp(.*)d batch(.*)time(.*)|(.*)cpp batch d(.*)|(.*)batch d cpp(.*))",
        ["your batch timing is '12.00 pm to 2.00 pm'"]
    ],
    [
        r"((.*)timing(.*)flutter(.*)batch a(.*)|(.*)flutter(.*)batch a(.*)timing(.*)|(.*)time(.*)flutter(.*)batch a(.*)|(.*)flutter(.*)batch a(.*)time(.*)|(.*)batch a flutter(.*)time(.*)|(.*)batch a flutter(.*)timing(.*)|(.*)timing(.*)batch a flutter(.*)|(.*)time(.*)batch a flutter(.*)|(.*)timing(.*)flutter(.*)a batch(.*)|(.*)flutter(.*)a batch(.*)timing(.*)|(.*)time(.*)flutter(.*)a batch(.*)|(.*)flutter(.*)a batch(.*)time(.*)|(.*)flutter batch a(.*)|(.*)batch a flutter(.*))",
        ["your batch timing is '09.00 am to 11.00 am'"]
    ],
    [
        r"((.*)timing(.*)(js|java script)(.*)batch a(.*)|(.*)(js|java script)(.*)batch a(.*)timing(.*)|(.*)time(.*)(js|java script)(.*)batch a(.*)|(.*)(js|java script)(.*)batch a(.*)time(.*)|(.*)batch a (js|java script)(.*)time(.*)|(.*)batch a (js|java script)(.*)timing(.*)|(.*)timing(.*)batch a (js|java script)(.*)|(.*)time(.*)batch a (js|java script)(.*)|(.*)timing(.*)(js|java script)(.*)a batch(.*)|(.*)(js|java script)(.*)a batch(.*)timing(.*)|(.*)time(.*)(js|java script)(.*)a batch(.*)|(.*)(js|java script)(.*)a batch(.*)time(.*)|(.*)(js|java script) batch a(.*)|(.*)batch a (js|java script)(.*))",
        ["your batch timing is '11.00 am to 01.00 pm'"]
    ],
    [
        r"((.*)timing(.*)(c logical|logical c)(.*)batch f(.*)|(.*)(c logical|logical c)(.*)batch f(.*)timing(.*)|(.*)time(.*)(c logical|logical c)(.*)batch f(.*)|(.*)(c logical|logical c)(.*)batch f(.*)time(.*)|(.*)batch f (c logical|logical c)(.*)time(.*)|(.*)batch f (c logical|logical c)(.*)timing(.*)|(.*)timing(.*)batch f (c logical|logical c)(.*)|(.*)time(.*)batch f (c logical|logical c)(.*)|(.*)timing(.*)(c logical|logical c)(.*)f batch(.*)|(.*)(c logical|logical c)(.*)f batch(.*)timing(.*)|(.*)time(.*)(c logical|logical c)(.*)f batch(.*)|(.*)(c logical|logical c)(.*)f batch(.*)time(.*)|(.*)(c logical|logical c) batch f(.*)|(.*)batch f (c logical|logical c))",
        ["your batch timing is '01.30 pm to 03.30 pm'"]
    ],
    [
        r"((.*)timing(.*)aws(.*)batch (c|d)(.*)|(.*)aws(.*)batch (c|d)(.*)timing(.*)|(.*)time(.*)aws(.*)batch (c|d)(.*)|(.*)aws(.*)batch (c|d)(.*)time(.*)|(.*)batch (c|d) aws(.*)time(.*)|(.*)batch (c|d) aws(.*)timing(.*)|(.*)timing(.*)batch (c|d) aws(.*)|(.*)time(.*)batch (c|d) aws(.*)|(.*)timing(.*)aws(.*)(c|d) batch(.*)|(.*)aws(.*)(c|d) batch(.*)timing(.*)|(.*)time(.*)aws(.*)(c|d) batch(.*)|(.*)aws(.*)(c|d) batch(.*)time(.*)|(.*)aws batch (c|d)(.*)|(.*)batch (c|d) aws(.*))",
        ["your batch timing is '03.30 pm to 05.00 pm'"]
    ],
    [
        r"(.*)ceo(.*)",
        ["Mr.Shivam Maheshwari"]
    ],
    [
        r"(.*)new (branch|office) location(.*)|(.*)location of new (branch|office)|(.*)new(.*)location(.*)|(.*)location(.*)new(.*)|(.*)new office(.*)|(.*)office new(.*)",
        ["2nd floor near kawasaki bike showroom tower tonk road jaipur"]
    ],
    [
        r"(.*)old (branch|office) location(.*)|(.*)location of old (branch|office)|(.*)old(.*)location(.*)|(.*)location(.*)old(.*)|(.*)old office(.*)|(.*)office old(.*)",
        ["b-35 second floor , vasant ahar colony ,gopalpura bypass road , jaipur rajasthan"]
    ],
    [
       r"(.*)course(.*)",
        ["we are provide Data Science,Java Fullstack Developer,AWS \n if you want to get deatils about any course please write "]
    ],
    [
        r"(data science|ml|machine learning)",
        ["course name = Data Science , course duration = 10 month ,  fees = 40000 , content = python , numpy , pandas , machine learning , deep learning ,Natural language processing,open cv \n"]
    ],
    [
        r"(java|java developer|java full stack developer|full stack developer)",
        ["course name = Java full stack developer, course duration = 10 month , fees = 40000"]
    ],
    [
        r"(aws|amazon web services)",
        ["course name = Amazon Web Services ,course duration = 10 month , fees = 40000"]
    ],
    [
        r"(.*)time(.*)",
        ["witch batch you want to get timming"]
    ]
]

# %%
print("==> if you want to get details about the course then write 'course'\n==> if you want to get batch timing then write 'time' ")
def chat_boat():
    chat=Chat(pairs,reflections)
    chat.converse()
# Out:
# ==> if you want to get details about the course then write 'course'
# ==> if you want to get batch timing then write 'time'

# %%
chatbot = Chat(pairs, reflections)


# def voice(text):
#     # Create a gTTS object
#     tts = gTTS(text)

#     # Save the speech to a temporary file
#     tts.save("output.mp3")

#     # Play the speech using the default audio player
#     os.system("output.mp3")
    
import pyttsx3

# Initialize the text-to-speech engine
engine = pyttsx3.init()

# Function to convert text to speech and speak it
def text_to_speech(text):
    engine.say(text)
    engine.runAndWait()

# %%
# Initialize the recognizer
recognizer = sr.Recognizer()

# Capture audio from a microphone
def speech():
    with sr.Microphone() as source:
        print("Please speak something...")
        audio = recognizer.listen(source)
        
        # Recognize the speech using Google Web Speech API
        try:
            text = recognizer.recognize_google(audio)
            print(f"Text: {text}")
        except sr.UnknownValueError:
            print("Could not understand the audio")
        except sr.RequestError as e:
            print(f"Error: {e}")
        while text.lower() != "exit":
            text = chatbot.respond(text)
            
            text_to_speech(text)
            speech()

# %%
user_input1=int(input('''if you want to connect with HR  with  voice presss 1 \n
and then press 0 for  text'''))
if user_input1 ==  0 :
    print("Welcome")
    print("please write your Question")
    chat_boat()
elif user_input1 == 1 :
    print("Welcome")
    speech()
# Out:
# if you want to connect with HR  with  voice presss 1
#
# and then press 0 for  text1
# Welcome
# Please speak something...
# Text: hello
# Please speak something...
# Text: worry about my best friend future and please provide me some detail about my best friend Shubham future
# Please speak something...
# Could not understand the audio
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[6], line 9
#       7 elif user_input1 == 1 :
#       8     print("Welcome")
# ----> 9     speech()
#
# Cell In[5], line 22, in speech()
#      19 text = chatbot.respond(text)
#      21 text_to_speech(text)
# ---> 22 speech()
#
# Cell In[5], line 22, in speech()
#      19 text = chatbot.respond(text)
#      21 text_to_speech(text)
# ---> 22 speech()
#
# Cell In[5], line 18, in speech()
#      16 except sr.RequestError as e:
#      17     print(f"Error: {e}")
# ...
