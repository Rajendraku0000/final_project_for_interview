# %%
# !pip install SpeechRecognition
# Out:
# Collecting SpeechRecognition
#   Downloading SpeechRecognition-3.10.0-py2.py3-none-any.whl (32.8 MB)
#      ---------------------------------------- 32.8/32.8 MB 6.2 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.26.0 in c:\users\rajen\anaconda3\lib\site-packages (from SpeechRecognition) (2.28.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\rajen\anaconda3\lib\site-packages (from requests>=2.26.0->SpeechRecognition) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\rajen\anaconda3\lib\site-packages (from requests>=2.26.0->SpeechRecognition) (2023.5.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\rajen\anaconda3\lib\site-packages (from requests>=2.26.0->SpeechRecognition) (1.26.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\rajen\anaconda3\lib\site-packages (from requests>=2.26.0->SpeechRecognition) (2.0.4)
# Installing collected packages: SpeechRecognition
# Successfully installed SpeechRecognition-3.10.0

# %%
# !pip install pyaudio
# Out:
# Requirement already satisfied: pyaudio in c:\users\rajen\anaconda3\lib\site-packages (0.2.13)

# %%
import speech_recognition as sr

# Initialize the recognizer
recognizer = sr.Recognizer()

# Capture audio from a microphone
with sr.Microphone() as source:
    print("Please speak something...")
    audio = recognizer.listen(source)

# Recognize the speech using Google Web Speech API
try:
    text = recognizer.recognize_google(audio)
    print(f"Text: {text}")
except sr.UnknownValueError:
    print("Could not understand the audio")
except sr.RequestError as e:
    print(f"Error: {e}")
# Out:
# Please speak something...
# Text: my name is Rajendra Kumar and Gopal is my brother

# %%
pip install gTTS
# Out:
# Collecting gTTS
#   Downloading gTTS-2.3.2-py3-none-any.whl (28 kB)
# Requirement already satisfied: click<8.2,>=7.1 in c:\users\rajen\anaconda3\lib\site-packages (from gTTS) (8.0.4)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\rajen\anaconda3\lib\site-packages (from gTTS) (2.28.1)
# Requirement already satisfied: colorama in c:\users\rajen\anaconda3\lib\site-packages (from click<8.2,>=7.1->gTTS) (0.4.6)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\rajen\anaconda3\lib\site-packages (from requests<3,>=2.27->gTTS) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\rajen\anaconda3\lib\site-packages (from requests<3,>=2.27->gTTS) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\rajen\anaconda3\lib\site-packages (from requests<3,>=2.27->gTTS) (2023.5.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\rajen\anaconda3\lib\site-packages (from requests<3,>=2.27->gTTS) (3.4)
# Installing collected packages: gTTS
# Successfully installed gTTS-2.3.2
# Note: you may need to restart the kernel to use updated packages.

# %%
from gtts import gTTS
import IPython.display as ipd

# Text to be converted to speech
text="chala ja bosddi ke os bahen chod ka kuch nahi ho sakta vo sirf ladki pattane me buzy he"

# Create a gTTS object
tts = gTTS(text)

# Save the speech to an audio file (optional)
tts.save("output.mp3")

# Play the speech
ipd.Audio("output.mp3")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
